# %%
import smopy
# %matplotlib inline
map = smopy.Map((47.54390,7.58816), z=18)
map.show_ipython()

# %%
x, y = map.to_pixels(47.54390, 7.58816)
ax = map.show_mpl(figsize=(8, 6));
ax.plot(x, y, 'or', ms=10, mew=2);

# %%
fig = ax.figure

fig = fig.savefig('map.png')
